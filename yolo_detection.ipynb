# %%
# !git clone https://github.com/AlexeyAB/darknet
# Out:
# fatal: destination path 'darknet' already exists and is not an empty directory.

# %%
# %cd darknet
# !sed -i 's/OPENCV=0/OPENCV=1/' Makefile
# !sed -i 's/GPU=0/GPU=1/' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/' Makefile
# Out:
# [Errno 2] No such file or directory: 'darknet'
# /content
# sed: can't read Makefile: No such file or directory
# sed: can't read Makefile: No such file or directory
# sed: can't read Makefile: No such file or directory

# %%
# !/usr/local/cuda/bin/nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2019 NVIDIA Corporation
# Built on Sun_Jul_28_19:07:16_PDT_2019
# Cuda compilation tools, release 10.1, V10.1.243

# %%
# !make
# Out:
# make: *** No targets specified and no makefile found.  Stop.

# %%
# !wget https://pjreddie.com/media/files/yolov3.weights
# Out:
# --2020-10-16 12:15:06--  https://pjreddie.com/media/files/yolov3.weights
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 248007048 (237M) [application/octet-stream]
# Saving to: ‘yolov3.weights’
#
# yolov3.weights      100%[===================>] 236.52M   175KB/s    in 22m 7s
#
# 2020-10-16 12:37:14 (183 KB/s) - ‘yolov3.weights’ saved [248007048/248007048]

# %%
# def imShow(path):
#   import cv2
#   import matplotlib.pyplot as plt
#   %matplotlib inline

#   image = cv2.imread(path)
#   height, width = image.shape[:2]
#   resized_image = cv2.resize(image,(3*width, 3*height), interpolation = cv2.INTER_CUBIC)

#   fig = plt.gcf()
#   fig.set_size_inches(18, 10)
#   plt.axis("off")
#   plt.imshow(cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB))
#   plt.show()

# %%
# !./darknet detect cfg/yolov3.cfg yolov3.weights.1 images/car.jpg
import numpy as np
import os
import cv2
import argparse
import time

image="/content/drive/My Drive/images/prediction_images/car1.jpeg"
yolo_weights="/content/yolov3.weights"
confidence=0.5
non_max_threshold=0.3

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %% [markdown]
# # New section

# %% [markdown]
# # New section
